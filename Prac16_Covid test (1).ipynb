# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('covid_vaccine_statewise.csv')
df
# Out:
#       Updated On        State  Total Individuals Registered  \
# 0     16/01/2021        India                     6943622.0
# 1     17/01/2021        India                     7119567.0
# 2     18/01/2021        India                     7150780.0
# 3     19/01/2021        India                     7423057.0
# 4     20/01/2021        India                     7555207.0
# ...          ...          ...                           ...
# 3547  17/04/2021  West Bengal                     7577053.0
# 3548  18/04/2021  West Bengal                     7593056.0
# 3549  19/04/2021  West Bengal                     7701111.0
# 3550  20/04/2021  West Bengal                     7830594.0
# 3551  21/04/2021  West Bengal                     7934464.0
#
#       Total Sessions Conducted  Total Sites   First Dose Administered  \
# 0                       3455.0        2957.0                  48276.0
# 1                       8532.0        4954.0                  58604.0
# ...

# %%
df.tail()
# Out:
#       Updated On        State  Total Individuals Registered  \
# 3547  17/04/2021  West Bengal                     7577053.0
# 3548  18/04/2021  West Bengal                     7593056.0
# 3549  19/04/2021  West Bengal                     7701111.0
# 3550  20/04/2021  West Bengal                     7830594.0
# 3551  21/04/2021  West Bengal                     7934464.0
#
#       Total Sessions Conducted  Total Sites   First Dose Administered  \
# 3547                  366910.0        1943.0                7577053.0
# 3548                  489171.0        2889.0                7593056.0
# 3549                  604585.0        3414.0                7701111.0
# 3550                  490740.0        2747.0                7830594.0
# 3551                  459350.0        2437.0                7934464.0
#
#       Second Dose Administered  Male(Individuals Vaccinated)  \
# 3547                 1162663.0                     4060679.0
# ...

# %%
df.head()
# Out:
#    Updated On  State  Total Individuals Registered  Total Sessions Conducted  \
# 0  16/01/2021  India                     6943622.0                    3455.0
# 1  17/01/2021  India                     7119567.0                    8532.0
# 2  18/01/2021  India                     7150780.0                   13611.0
# 3  19/01/2021  India                     7423057.0                   17855.0
# 4  20/01/2021  India                     7555207.0                   25472.0
#
#    Total Sites   First Dose Administered  Second Dose Administered  \
# 0        2957.0                  48276.0                       0.0
# 1        4954.0                  58604.0                       0.0
# 2        6583.0                  99449.0                       0.0
# 3        7951.0                 195525.0                       0.0
# 4       10504.0                 251280.0                       0.0
#
#    Male(Individuals Vaccinated)  Female(Individuals Vaccinated)  \
# ...

# %%
df.shape
# Out:
# (3552, 14)

# %%
df.isnull()
# Out:
#       Updated On  State  Total Individuals Registered  \
# 0          False  False                         False
# 1          False  False                         False
# 2          False  False                         False
# 3          False  False                         False
# 4          False  False                         False
# ...          ...    ...                           ...
# 3547       False  False                         False
# 3548       False  False                         False
# 3549       False  False                         False
# 3550       False  False                         False
# 3551       False  False                         False
#
#       Total Sessions Conducted  Total Sites   First Dose Administered  \
# 0                        False         False                    False
# 1                        False         False                    False
# 2                        False         False                    False
# ...

# %%
df.isnull().sum()
# Out:
# Updated On                             0
# State                                  0
# Total Individuals Registered           8
# Total Sessions Conducted               7
# Total Sites                            7
# First Dose Administered                7
# Second Dose Administered               7
# Male(Individuals Vaccinated)           7
# Female(Individuals Vaccinated)         7
# Transgender(Individuals Vaccinated)    7
# Total Covaxin Administered             7
# Total CoviShield Administered          7
# Total Individuals Vaccinated           7
# Total Doses Administered               0
# dtype: int64

# %%
df.drop(columns = ['State'])
# Out:
#       Updated On  Total Individuals Registered  Total Sessions Conducted  \
# 0     16/01/2021                     6943622.0                    3455.0
# 1     17/01/2021                     7119567.0                    8532.0
# 2     18/01/2021                     7150780.0                   13611.0
# 3     19/01/2021                     7423057.0                   17855.0
# 4     20/01/2021                     7555207.0                   25472.0
# ...          ...                           ...                       ...
# 3547  17/04/2021                     7577053.0                  366910.0
# 3548  18/04/2021                     7593056.0                  489171.0
# 3549  19/04/2021                     7701111.0                  604585.0
# 3550  20/04/2021                     7830594.0                  490740.0
# 3551  21/04/2021                     7934464.0                  459350.0
#
#       Total Sites   First Dose Administered  Second Dose Administered  \
# ...

# %%
df.describe()
# Out:
#        Total Individuals Registered  Total Sessions Conducted   Total Sites   \
# count                  3.544000e+03              3.545000e+03    3545.000000
# mean                   1.965572e+06              1.320204e+05    3092.627645
# std                    7.853042e+06              7.146332e+05   10475.815355
# min                    7.420000e+02              1.000000e+00       1.000000
# 25%                    7.450200e+04              1.100000e+03     118.000000
# 50%                    3.749730e+05              7.346000e+03     668.000000
# 75%                    1.192318e+06              4.674300e+04    2396.000000
# max                    1.116734e+08              1.078696e+07  124323.000000
#
#        First Dose Administered  Second Dose Administered  \
# count             3.545000e+03              3.545000e+03
# mean              1.658049e+06              2.614206e+05
# std               7.514886e+06              1.152397e+06
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3552 entries, 0 to 3551
# Data columns (total 14 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Updated On                           3552 non-null   object
#  1   State                                3552 non-null   object
#  2   Total Individuals Registered         3544 non-null   float64
#  3   Total Sessions Conducted             3545 non-null   float64
#  4   Total Sites                          3545 non-null   float64
#  5   First Dose Administered              3545 non-null   float64
#  6   Second Dose Administered             3545 non-null   float64
#  7   Male(Individuals Vaccinated)         3545 non-null   float64
#  8   Female(Individuals Vaccinated)       3545 non-null   float64
#  9   Transgender(Individuals Vaccinated)  3545 non-null   float64
#  10  Total Covaxin Administered           3545 non-null   float64
# ...

# %%
df.head(3552)
# Out:
#       Updated On        State  Total Individuals Registered  \
# 0     16/01/2021        India                     6943622.0
# 1     17/01/2021        India                     7119567.0
# 2     18/01/2021        India                     7150780.0
# 3     19/01/2021        India                     7423057.0
# 4     20/01/2021        India                     7555207.0
# ...          ...          ...                           ...
# 3547  17/04/2021  West Bengal                     7577053.0
# 3548  18/04/2021  West Bengal                     7593056.0
# 3549  19/04/2021  West Bengal                     7701111.0
# 3550  20/04/2021  West Bengal                     7830594.0
# 3551  21/04/2021  West Bengal                     7934464.0
#
#       Total Sessions Conducted  Total Sites   First Dose Administered  \
# 0                       3455.0        2957.0                  48276.0
# 1                       8532.0        4954.0                  58604.0
# ...

# %%
df
# Out:
#       Updated On        State  Total Individuals Registered  \
# 0     16/01/2021        India                     6943622.0
# 1     17/01/2021        India                     7119567.0
# 2     18/01/2021        India                     7150780.0
# 3     19/01/2021        India                     7423057.0
# 4     20/01/2021        India                     7555207.0
# ...          ...          ...                           ...
# 3547  17/04/2021  West Bengal                     7577053.0
# 3548  18/04/2021  West Bengal                     7593056.0
# 3549  19/04/2021  West Bengal                     7701111.0
# 3550  20/04/2021  West Bengal                     7830594.0
# 3551  21/04/2021  West Bengal                     7934464.0
#
#       Total Sessions Conducted  Total Sites   First Dose Administered  \
# 0                       3455.0        2957.0                  48276.0
# 1                       8532.0        4954.0                  58604.0
# ...

# %% [markdown]
# ## Number of Person statewise vaccinated for first dose in India

# %%
df.groupby('State')['First Dose Administered'].sum()
# Out:
# State
# Andaman and Nicobar Islands                 1.346603e+06
# Andhra Pradesh                              1.167716e+08
# Arunachal Pradesh                           4.312451e+06
# Assam                                       4.589515e+07
# Bihar                                       1.363895e+08
# Chandigarh                                  3.544345e+06
# Chhattisgarh                                1.102192e+08
# Dadra and Nagar Haveli and Daman and Diu    1.409718e+06
# Delhi                                       5.793644e+07
# Goa                                         5.497478e+06
# Gujarat                                     2.621423e+08
# Haryana                                     7.072065e+07
# Himachal Pradesh                            2.688306e+07
# India                                       2.940476e+09
# Jammu and Kashmir                           3.958096e+07
# Jharkhand                                   6.967216e+07
# ...

# %% [markdown]
# ## Number of Person statewise vaccinated for second dose in India

# %%
df.groupby('State')['Second Dose Administered'].sum()
# Out:
# State
# Andaman and Nicobar Islands                    243995.0
# Andhra Pradesh                               20533459.0
# Arunachal Pradesh                             1152356.0
# Assam                                         8301918.0
# Bihar                                        21818777.0
# Chandigarh                                     644173.0
# Chhattisgarh                                 15780785.0
# Dadra and Nagar Haveli and Daman and Diu       241484.0
# Delhi                                        12753592.0
# Goa                                           1095110.0
# Gujarat                                      40522480.0
# Haryana                                       8825619.0
# Himachal Pradesh                              4562089.0
# India                                       463420514.0
# Jammu and Kashmir                             6839847.0
# Jharkhand                                    11372418.0
# Karnataka                                    25505189.0
# ...

# %% [markdown]
# # # Number of Females vaccinated

# %%
df['Female(Individuals Vaccinated)'].sum()
# Out:
# 2805089294.0

# %%
df['Male(Individuals Vaccinated)'].sum()
# Out:
# 3072022958.0
